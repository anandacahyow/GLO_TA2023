# %% [markdown]
# WELL 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original data points
x = [1, 2, 3]  # X-coordinates
x = [30, 100, 120, 160, 180]  # X-coordinates
y = [21.99, 20.45, 13.36, 18.63, 19.69]  # Y-coordinates WELL 1
rmse_well2 = [22.77, 11.08, 22.14] # Y-coordinates WELL 2

# Generate 100 data points between the first and last x-values
x_new = np.linspace(x[0], x[-1], num=100)

# Perform linear interpolation
coefficients = np.polyfit(x, y, 2)
y_new = np.polyval(coefficients, x_new)

# Print the interpolated data
for i in range(len(x_new)):
    #print(f"{x_new[i]:.2f} {y_new[i]:.2f}")
    True

plt.plot(x_new,y_new,label='Interpolated Curve',color='#0014DC')
plt.plot(x,y,'o',label='RMSE Data',color='orange')
plt.grid()
plt.title("Model Complexity Curve\nof Well OA-11 LSTM Dynamics Model")
plt.xlabel("Mean of Total Neuron Per Layer")
plt.ylabel("RMSE")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original data points
x = [1, 2, 3]  # X-coordinates
x = [180,60,181,360,90,210,360,480,540]  # X-coordinates
y = [20.96,22.91,19.97,21.02,21.99,20.45,13.36,18.63,19.69]  # Y-coordinates WELL 1
rmse_well2 = [22.77, 11.08, 22.14] # Y-coordinates WELL 2

# Generate 100 data points between the first and last x-values
x_new = np.linspace(min(x), max(x), num=100)

# Perform linear interpolation
coefficients = np.polyfit(x, y, 6)
y_new = np.polyval(coefficients, x_new)

# Print the interpolated data
for i in range(len(x_new)):
    #print(f"{x_new[i]:.2f} {y_new[i]:.2f}")
    True

plt.plot(x_new,y_new,label='Interpolated Curve',color='#0014DC')
plt.plot(x,y,'o',label='RMSE Data',color='orange')
plt.grid()
plt.title("Model Complexity Curve\nof Well OA-11 LSTM Dynamics Model")
plt.xlabel("Mean of Total Neuron Per Layer")
plt.ylabel("RMSE")
plt.legend()

# %% [markdown]
# WELL 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original data points
x = [1, 2, 3]  # X-coordinates
x = [30, 100, 120, 160, 180]  # X-coordinates
y = [21.99, 17.26, 13.36, 14.48, 19.69]  # Y-coordinates WELL 1
#y = [22.77, 11.08, 22.14] # Y-coordinates WELL 2

# Generate 100 data points between the first and last x-values
x_new = np.linspace(x[0], x[-1], num=100)

# Perform linear interpolation
coefficients = np.polyfit(x, y, 2)
y_new = np.polyval(coefficients, x_new)

# Print the interpolated data
for i in range(len(x_new)):
    #print(f"{x_new[i]:.2f} {y_new[i]:.2f}")
    True

plt.plot(x_new,y_new,label='Interpolated Curve',color='#0014DC')
plt.plot(x,y,'o',label='RMSE Data',color='orange')
plt.grid()
plt.title("Model Complexity Curve\nof Well OA-12 LSTM Dynamics Model")
plt.xlabel("Mean of Total Neuron Per Layer")
plt.ylabel("RMSE")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Original data points
x = [1, 2, 3]  # X-coordinates
x = [180,60,181,360,90,210,361,480,540]  # X-coordinates
y = [18.62,24.75,13.46,27.05,22.77,17.26,11.08,14.48,22.14]  # Y-coordinates WELL 1
#y = [22.77, 11.08, 22.14] # Y-coordinates WELL 2

# Generate 100 data points between the first and last x-values
x_new = np.linspace(min(x), max(x), num=100)

# Perform linear interpolation
coefficients = np.polyfit(x, y, 2)
y_new = np.polyval(coefficients, x_new)

# Print the interpolated data
for i in range(len(x_new)):
    #print(f"{x_new[i]:.2f} {y_new[i]:.2f}")
    True

plt.plot(x_new,y_new,label='Interpolated Curve',color='#0014DC')
plt.plot(x,y,'o',label='RMSE Data',color='orange')
plt.grid()
plt.title("Model Complexity Curve\nof Well OA-12 LSTM Dynamics Model")
plt.xlabel("Mean of Total Neuron Per Layer")
plt.ylabel("RMSE")
plt.legend()
